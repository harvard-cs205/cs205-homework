# %%
serial = 347.58

# %%
p1=347.58
p2=694.65
p4=1381.52
p12=3626.13

# %%
p1_avx = 1133.18661272
p2_avx = 1428.17481115 
p4_avx = 2256.47039758

p12_avx = 3389.69946475

# %%
thread_list = [1, 2, 4, 12]
p_list = [p1, p2, p4, p12]
p_avx_list = [p1_avx, p2_avx, p4_avx, p12_avx]

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

# %%
sns.set_context('poster', font_scale=1.25)

# %%
plt.plot(thread_list, p_list, label='Threading', marker='.')
plt.plot(thread_list, p_avx_list, label='Threading and AVX', marker='.')
