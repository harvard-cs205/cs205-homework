# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

# %%
sns.set_context('poster', font_scale=1.25)

# %%
num_threads = [1, 2, 3, 4]
timing = [
    4.41142241955,
    2.53045721054,
    2.89352252483,
    2.20505132675
]

num_threads = np.array(num_threads)
timing = np.array(timing)

# %%
plt.plot(num_threads, timing, ls='-', marker='.')
plt.ylabel('Average Time Elapsed over 10 runs (s)')
plt.xlabel('Number of Threads')
plt.title('Average Execution time vs. Number of Threads')

plt.savefig('time_vs_threads.png', dpi=200, bbox_inches='tight')

# %%
plt.plot(num_threads, timing[0]/timing, ls='-', marker='.')
plt.ylabel('Average Speedup (Serial Time / New Time)')
plt.xlabel('Number of Threads')
plt.title('Speedup vs. Number of Threads')

plt.savefig('speedup_vs_threads.png', dpi=200, bbox_inches='tight')
