# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns
sns.set_context('poster', font_scale=1.25)

# %%
from morton import zorder

# %%
grid_size = 768

# %%
index_mat = np.arange(grid_size**2).reshape((grid_size, grid_size))

# %%
import skimage as ski
import skimage.io

# %%
ski.io.imshow(index_mat)
plt.grid(False)
plt.savefig('standard_logical_indices.png', dpi=200, bbox_inches='tight')

# %%
ordered_mat = index_mat.copy()
zorder(ordered_mat)

# %%
ski.io.imshow(ordered_mat)
plt.grid(False)
plt.savefig('morton_ordering.png', dpi=200, bbox_inches='tight')

# %%
ski.io.imshow(ordered_mat[0:100, 0:100])
plt.grid(False)
plt.savefig('morton_ordering_zoomed.png', dpi=200, bbox_inches='tight')
