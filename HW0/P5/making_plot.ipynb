# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

# %%
sns.set_context('poster', font_scale=1.25)

# %%
# Note that we made the xscale start at N=2, or else it doesn't make sense

N = np.logspace(np.log10(2), 6, num=500)
t_alone = N - 1
t_infinite = np.log2(N)
plt.loglog(N, t_alone, label='One Cashier')
plt.loglog(N, t_infinite, label='Infinite Cashiers')

plt.legend(loc='best')

plt.xlabel(r'$N$ Bags')
plt.ylabel(r'Time (s)')
plt.title(r'Time Required to Count $N$ Bags')
plt.savefig('P5.png')
