# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


# Create the N array
N= np.linspace(1,128,128)
plt.close('all')
plt.figure()
plt.hold(True)
plt.plot(N,np.log2(N))
plt.plot(N,N-1)
plt.legend(['Infinte employees','1 employee'],loc=2)
plt.xlabel('Number of bags')
plt.ylabel('Counting time')
plt.savefig('P5.png')
