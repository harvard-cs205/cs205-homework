# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


#p4 = np.loadtxt('P4/P4_trajectory.txt', delimiter=',', usecols=[0,1,2])

p4 = np.loadtxt('P4/P4_trajectory.txt', delimiter=',', unpack=True)

# %%
ax = Axes3D(plt.figure())
ax.plot(p4[0], p4[1], p4[2], '--b', label='True trajectory')
plt.show()

# %%
s
# Out:
# array([[  0.00000000e+00,   1.50000000e-01,   3.02010000e-01,
#           4.55670000e-01,   6.06170000e-01,   7.58730000e-01,
#           9.06870000e-01,   1.05760000e+00,   1.20910000e+00,
#           1.35670000e+00,   1.50070000e+00,   1.64250000e+00,
#           1.79060000e+00,   1.93880000e+00,   2.08480000e+00,
#           2.23790000e+00,   2.38570000e+00,   2.53430000e+00,
#           2.68140000e+00,   2.82650000e+00,   2.97230000e+00,
#           3.11890000e+00,   3.26450000e+00,   3.40920000e+00,
#           3.55120000e+00,   3.69170000e+00,   3.83140000e+00,
#           3.97040000e+00,   4.10160000e+00,   4.23250000e+00,
#           4.36270000e+00,   4.49380000e+00,   4.62320000e+00,
#           4.75330000e+00,   4.87840000e+00,   5.00360000e+00,
#           5.12990000e+00,   5.25780000e+00,   5.38510000e+00,
#           5.51780000e+00,   5.65420000e+00,   5.79510000e+00,
#           5.93380000e+00,   6.07030000e+00,   6.20900000e+00,
# ...
