# %%
import findspark
findspark.find()
findspark.init(edit_profile=True)
import pyspark
sc = pyspark.SparkContext()

# %%
import re
import copy

# %%
rawData = sc.textFile('pg100.txt')

# %%
wlist = rawData.flatMap(lambda x: x.split(' ')).filter(lambda x: not x.isdigit()).filter(lambda x: not x.isupper()).filter(lambda x: x != '')

# %%
withIndex = wlist.zipWithIndex().map(lambda (k,v): (v,k)) 
# withIndex.map(lambda x: (x[1], withIndex.lookup(x[0] + 1), withIndex.lookup(x[0] + 2))).take(10)

# %%
wlist_2 = wlist.collect()
word_seq = []
for i in xrange(len(wlist_2)-2):
    word_seq.append(((wlist_2[i], wlist_2[i+1]),wlist_2[i+2]))

word_seq = sc.parallelize(word_seq)
word_seq.map(lambda x: (x[0], (x[1], 1))).collect()
word_seq.reduceByKey(lambda x, y: (x[1][1]+x[1][1]))
# Out:
# [((u'so', u'was'), [u'he;', u'mine,', u'he', u'this.', u"I'll"]),
#  ((u"worship's", u'friend,'), [u'and']),
#  ((u'Faith,', u'some'), [u'certain']),
#  ((u'four.', u'Poins.'), [u'Ay,']),
#  ((u'honour', u'he'), [u"requir'd;"]),
#  ((u'Slender.', u"There's"), [u'his']),
#  ((u'appeal,', u'Which'), [u'then']),
#  ((u'Pandulph,', u'of'), [u'fair']),
#  ((u'Should', u'hold'), [u'her', u'up']),
#  ((u'sight', u'For'), [u'fear', u'terror,']),
#  ((u'paltry', u'fellow,'), [u'Long']),
#  ((u'Jul.', u'At'), [u'what']),
#  ((u'to', u'return.'), [u'Perchance', u'son,']),
#  ((u'of', u'crafty'), [u'knaves.']),
#  ((u'the', u'irregular'), [u'and']),
#  ((u'many', u'cowards,'), [u'whose']),
#  ((u'be', u'older'), [u'when']),
#  ((u'do', u'beg'), [u'your', u'his', u'of']),
#  ((u'What', u'tedious'), [u'homily']),
#  ((u'desire', u'Nothing'), [u'but']),
#  ((u'fearfully', u'believe'), [u"'tis"]),
#  ((u'answer', u'me!'), [u'My']),
#  ((u'The', u"pow'rs"), [u'that']),
#  ((u'lower', u'lie.'), [u'[Exit.]']),
#  ((u'has', u'thrice'), [u'her']),
#  ((u'sun-burnt', u'sicklemen,'), [u'of']),
#  ((u'of', u'birth,'),
#   [u'Whose', u'Lives', u'The', u'your', u'Yet', u'Prerogative']),
#  ((u'good', u'meat'), [u'into', u'in']),
#  ((u'this,', u'Whose'), [u'fall', u'mouth']),
#  ((u'therefore', u'fire.'), [u'Do']),
#  ((u"Is't", u'good'), [u'to']),
#  ((u'shed', u'remorseful'), [u'tear,']),
#  ((u'what', u"mean'st"), [u'thou']),
#  ((u'plays.', u'Enter'), [u'two', u'Wine,']),
#  ((u'throne;', u'The'), [u'blood']),
#  ((u"'tis", u'twice'), [u'two']),
#  ((u'wish', u'well.'), [u"'Tis"]),
#  ((u'second', u'Stood'), [u'heir']),
#  ((u"bodg'd", u'again;'), [u'as']),
#  ((u'and', u'fled.'), [u'Comfort,']),
#  ((u'some', u'unhappy'), [u'words.', u'passenger']),
#  ((u'such', u'apology:'), [u'do']),
#  ((u'handkerchief-', u'am'), [u'sure']),
#  ((u'you', u'well'),
#   [u'enough.',
#    u'enough.',
#    u"guerdon'd",
#    u'expounded',
#    u'at',
#    u"advis'd?",
#    u'till',
#    u'enough.',
#    u'and',
#    u'now.',
#    u'assured',
#    u'assured,',
#    u'in',
#    u"serv'd,",
#    u'and',
#    u'know',
#    u'To']),
#  ((u'unloose,', u'Familiar'), [u'as']),
#  ((u'to', u'Jaquenetta.'), [u'We']),
#  ((u'ends', u'all'), [u'other', u'counsel,']),
#  ((u'might', u'The'), [u'better']),
#  ((u'live?', u'Was'), [u'not']),
#  ((u'thou,', u'wretch?'), [u'Thy']),
#  ((u'mines!', u'Tell'), [u'you']),
#  ((u'again', u'assail'), [u'your']),
#  ((u'his', u'frailty,'), [u'many', u'and']),
#  ((u'high', u'heaven,'), [u'love']),
#  ((u'base', u'Shall'), [u'top']),
#  ((u'done', u'But'), [u'spoke', u'that']),
#  ((u'couch', u'on'), [u'flowers,']),
#  ((u'with', u'wax.'), [u'Our']),
#  ((u'did', u'beat'), [u'me']),
#  ((u'sweet,', u'Even'), [u'in']),
#  ((u'reasonable', u'demands.'), [u'But']),
#  ((u'our', u'miseries'), [u'our']),
#  ((u'death', u'an'), [u'hundred']),
#  ((u'and', u'perfect'), [u'image', u'chrysolite,']),
#  ((u'waking', u'looks'), [u'upon,']),
#  ((u'and', u'live'),
#   [u'on',
#    u'with',
#    u'here,',
#    u'cleanly,',
#    u'hence',
#    u'the',
#    u'without',
#    u'aye']),
#  ((u"others'", u'moan!'), [u"Harry's"]),
#  ((u'deathbed;', u'He'), [u'never']),
#  ((u'Ass,', u'doubt'), [u'not.']),
#  ((u'core', u'of'), [u'envy!']),
#  ((u'cheek;', u"'twas"), [u'just']),
#  ((u'But,', u'mistress,'), [u'know']),
#  ((u'was', u'he,'), [u'Speak,', u'Messala,']),
#  ((u'Since', u'thou,'), [u'created']),
#  ((u'pities', u'him,'), [u'For']),
#  ((u'match.', u'[Aside]'), [u'You']),
#  ((u'fine.', u'One'), [u'speech']),
#  ((u'have', u'there.'), [u'Exit']),
#  ((u'what;', u'but'), [u'take', u'it', u'formal', u'he']),
#  ((u'very', u'wound'), [u'of']),
#  ((u'barbarians,', u'as'), [u'they']),
#  ((u'Sir,', u'say'), [u'to', u'to']),
#  ((u'Doing', u'thee'), [u'vantage,']),
#  ((u'lawful', u'King?'), [u'Perhaps']),
#  ((u'and', u'mulberries;'), [u'The']),
#  ((u'Dive,', u'thoughts,'), [u'down']),
#  ((u'and', u'perish,'), [u'and']),
#  ((u'your', u'trial'), [u'in']),
#  ((u'ever', u'contradicted'), [u'your']),
#  ((u'as', u'ye'), [u'should', u'are;']),
#  ((u'young', u'affects'), [u'In']),
#  ((u'stockings', u"foul'd,"), [u"Ungart'red,"]),
#  ((u'honest.', u'Long'), [u'live']),
#  ((u'Were', u'most'), [u'impertinent.']),
#  ((u'do', u'turn'), [u'But', u'to', u'our']),
#  ((u'in', u"Rutland's"), [u'blood-']),
#  ((u'celebrate', u'This'), [u'feast']),
#  ((u'Seem', u'you'), [u'that']),
#  ((u'alone,', u'in'), [u"boy's", u'company,']),
#  ((u'despair;', u'that'), [u'way']),
#  ((u'look,', u'Possessing'), [u'or']),
#  ((u'Enobarbus.', u'tell'), [u'you']),
#  ((u"counterfeit'st", u'the'), [u'person']),
#  ((u'to', u'Pistol'), [u'Lords,']),
#  ((u'schoolmaster', u'a'), [u'constable']),
#  ((u'discovery', u'of'), [u'most', u'the']),
#  ((u'again.', u'would'), [u'have']),
#  ((u'say.', u'Hero.'), [u'No;']),
#  ((u'fear', u'The'), [u'native', u'smallest']),
#  ((u'Diffusest', u'honey'), [u'drops,']),
#  ((u'mine,', u'but'), [u'thine']),
#  ((u'Capitol;', u'Brutus'), [u"kill'd"]),
#  ((u'moon;', u'but,'), [u'methinks,']),
#  ((u'But,', u'Host,'), [u'doth']),
#  ((u'by', u'point'), [u'the']),
#  ((u"perjur'd,", u'and'), [u'thou']),
#  ((u'behaviours;', u'and'), [u'will']),
#  ((u'council', u'chamber.'), [u'The']),
#  ((u'intent', u'have'), [u"seduc'd"]),
#  ((u'sir.', u"Thou'rt"), [u'my']),
#  ((u"pigeon-liver'd", u'and'), [u'lack']),
#  ((u'To', u'overtake'), [u'thee.']),
#  ((u'blue', u'as'), [u'bilberry;']),
#  ((u'was', u'hither'), [u'brought']),
#  ((u'law;', u'Who'), [u'died']),
#  ((u'With', u'Lady'), [u'Margery,']),
#  ((u'bats', u'and'), [u'clubs?', u'clubs.']),
#  ((u'so!)', u'you'), [u'are']),
#  ((u'we', u'rich'), [u'in']),
#  ((u'Marcius,', u'help,'), [u'You']),
#  ((u'of', u'chase'), [u'should']),
#  ((u'posts', u'could'), [u'run,']),
#  ((u'such', u'interchange'), [u'of']),
#  ((u'her', u'last'), [u'breath,']),
#  ((u'was', u"amaz'd"), [u'Under']),
#  ((u'time.', u'Go'), [u'in']),
#  ((u'wiser', u'by'), [u'your']),
#  ((u'thing,', u'sir,'), [u'but']),
#  ((u'my', u'target,'), [u'thus.']),
#  ((u'discretion', u'with'), [u'a']),
#  ((u'man.', u'King.'), [u'heavy']),
#  ((u'proceeding!-if,', u'with'), [u'dear']),
#  ((u'liege,', u'did'), [u'deny']),
#  ((u'love,', u'be'), [u'moderate,']),
#  ((u'fight,', u'uncle?'), [u'Helenus!']),
#  ((u'gentle', u'master,'), [u'Are', u"receiv'd"]),
#  ((u'Rinaldo,', u'To'), [u'this']),
#  ((u'of', u'tears:'), [u'That']),
#  ((u'and', u'fiery'), [u'steed']),
#  ((u'hugs', u'his'), [u'kicky-wicky']),
#  ((u'lift', u'our'), [u'heads']),
#  ((u'accepted', u'pain.'), [u'Let']),
#  ((u'the', u'unbated'), [u'fire']),
#  ((u'granted', u'less,'), [u'Aufidius?']),
#  ((u'must', u'build'), [u'churches']),
#  ((u'their', u'helmets'), [u'and']),
#  ((u'letters', u'with'), [u'Free']),
#  ((u'him!', u"He's"), [u'a', u'a']),
#  ((u'Oberon,', u'and'), [u'make']),
#  ((u'This', u'place?'), [u'Mine']),
#  ((u'will?', u'Wife.'), [u'This']),
#  ((u'some', u"pitch'd"), [u'battle']),
#  ((u'here-fie,', u'fie,'), [u'fie']),
#  ((u"consum'd", u'with'), [u'fire', u'fire', u'fire;']),
#  ((u'It', u'can'), [u'do']),
#  ((u'madness.', u'Enter'), [u'Lo,', u'Madam,']),
#  ((u'Salique,', u'as'), [u'said,']),
#  ((u'Ber.', u"'Tis"), [u'now', u'here!']),
#  ((u'next', u'time'), [u'do', u'we', u'see']),
#  ((u'stroke', u'would'), [u'prove']),
#  ((u'High', u'dukes,'), [u'great']),
#  ((u'every', u'thing.'), [u'Re-enter']),
#  ((u'flattering', u'tongue'), [u'of']),
#  ((u'Bait', u'the'), [u'hook']),
#  ((u'knee', u'slaves,'), [u'vapours,']),
#  ((u'weather', u'too?'), [u'How']),
#  ((u'this', u'opportunity'), [u'you']),
#  ((u'Sir', u'Nathaniel]'), [u'Sir,']),
#  ((u'confessing', u'them,'), [u'the']),
#  ((u'run', u'thy'), [u'head']),
#  ((u'Servants].', u'By'), [u'no']),
#  ((u'courageous', u'day!'), [u'most']),
#  ((u"will's", u'free'), [u'hours']),
#  ((u'sun.', u'Could'), [u'we']),
#  ((u'weary', u'reckoning!'), [u'Pardon']),
#  ((u'hour!', u'Being'), [u'done,']),
#  ((u'forbid,', u'That'), [u'they']),
#  ((u'will', u'do.'), [u'Re-enter', u'But', u'Sir,', u"We'll"]),
#  ((u'dram', u'conjured'), [u'to']),
#  ((u'my', u'banishment,'), [u'and']),
#  ((u'second', u'storm'), [u'to']),
#  ((u'his', u'paw'), [u'And']),
#  ((u"Troilus'", u'chin.'), [u"An't"]),
#  ((u'mock', u'Diomed'), [u'again.']),
#  ((u'messenger', u'with'), [u'letters']),
#  ((u'tomb.', u'There'), [u'lives']),
#  ((u'my', u'doing'), [u'well', u'now:']),
#  ((u'set', u'else?'), [u'He']),
#  ((u'one', u"on's"), [u'ears']),
#  ((u'her', u'continual'), [u'tears']),
#  ((u'negligence', u'befriends'), [u'thee']),
#  ((u'Look', u'on'),
#   [u'this',
#    u'thy',
#    u'my',
#    u'me',
#    u'the',
#    u'her!',
#    u'beauty',
#    u'Master',
#    u'the',
#    u'my',
#    u'my',
#    u'me',
#    u'her,']),
#  ((u'follows', u'thus:'), [u'Thou']),
#  ((u'Paris', u'sleeps-and'), [u"that's"]),
#  ((u'poor,', u'too'), [u'weak']),
#  ((u'dead', u'with'), [u'nothing.', u'charity', u'grief,', u'grieving,']),
#  ((u'well.', u'Must'), [u'obey.']),
#  ((u'Persons', u'in'), [u'the']),
#  ((u'fairy', u'favours,'), [u'In']),
#  ((u'sleep', u'And'), [u'charge']),
#  ((u'knave?', u'Knight,'), [u'knight,']),
#  ((u'Madam,', u'Dinner'), [u'is']),
#  ((u'is.', u'To'), [u'shift', u'be']),
#  ((u"'ticed", u'me'), [u'hither']),
#  ((u'new?', u'Transform'), [u'me,']),
#  ((u'and', u'attract'), [u'more']),
#  ((u'his', u'fellows'), [u'fly;', u'but']),
#  ((u'die.', u'Thanks,'), [u'gentle']),
#  ((u'If', u'your'),
#   [u'lordship',
#    u'life',
#    u'master',
#    u'messenger',
#    u'mind',
#    u'father',
#    u'pure',
#    u'back',
#    u'business',
#    u'Grace',
#    u'honour',
#    u'diligence',
#    u'will',
#    u'ladyship',
#    u'worship',
#    u'leisure',
#    u'lass',
#    u'more']),
#  ((u'drudge', u'to'), [u'be,']),
#  ((u'Fifth', u'Was'), [u'in']),
#  ((u'blood', u'has'), [u'not']),
#  ((u'and', u'royal'), [u'interview,', u'eye', u'necessities']),
#  ((u'so!', u'For'), [u'what', u'have']),
#  ((u'[disguised].', u'Kent.'), [u'If']),
#  ((u'but', u'success'), [u'Will']),
#  ((u'of', u'me:'), [u'there', u'to', u'Lucrece']),
#  ((u'whose', u'hand'), [u'has', u'give', u'must', u'shall']),
#  ((u'farewell;', u'am'), [u'in']),
#  ((u'the', u'fox'),
#   [u'ere',
#    u'for',
#    u'Who,',
#    u'surveyor',
#    u'hath',
#    u'carries',
#    u'would',
#    u'would']),
#  ((u'thee', u'out.'), [u'[Trumpets', u'go.', u'thank']),
#  ((u'Villainous', u'whore!'), [u'She']),
#  ((u'shields', u'before'), [u'your']),
#  ((u'away,', u'man;'), [u'was']),
#  ((u'without', u'seeming'), [u'so.']),
#  ((u'not', u'wasted'), [u'it,']),
#  ((u'intents?', u'We'), [u'shall']),
#  ((u'his', u"hell-govern'd"), [u'arm']),
#  ((u'and', u'calves'), [u'which']),
#  ((u'half', u"din'd"), [u'on']),
#  ((u'Angus.', u'worthiest'), [u'cousin!']),
#  ((u'Our', u'instruments'), [u'to']),
#  ((u'living', u'art.'), [u'You']),
#  ((u'Bene.', u'Lady,'), [u'were']),
#  ((u'man', u'that'),
#   [u'had',
#    u'will',
#    u'hath',
#    u'had',
#    u'hath',
#    u'fears',
#    u'gave',
#    u'were',
#    u"Fortune's",
#    u'sits',
#    u'was',
#    u'love',
#    u'he',
#    u'dies',
#    u'once',
#    u'has',
#    u'sees',
#    u"ne'er",
#    u'slew',
#    u'took',
#    u'stood',
#    u'has',
#    u'hangs',
#    u'hopes',
#    u'more',
#    u'would',
#    u'makes',
#    u'dares',
#    u'function',
#    u"wrong'd",
#    u'apprehends',
#    u'never',
#    u'you',
#    u'hath',
#    u"beguil'd",
#    u'were',
#    u'knows',
#    u'knew',
#    u'languishes',
#    u'all',
#    u'mocks',
#    u'Bolingbroke',
#    u'but',
#    u'did',
#    u'loves',
#    u'keeps',
#    u'means',
#    u'respects',
#    u'must',
#    u'slew',
#    u'can',
#    u'hath',
#    u'leapt;',
#    u"e'er",
#    u'is',
#    u'gives',
#    u'ever',
#    u'hath',
#    u'takes',
#    u'hath',
#    u'does',
#    u'grazed']),
#  ((u'your', u'foes'), [u'but']),
#  ((u'quick', u'condition'), [u'That']),
#  ((u'and', u'foison'), [u'of']),
#  ((u'pray', u'to-morrow.'), [u'Gallants,']),
#  ((u'these', u'degrees'), [u'have']),
#  ((u'wolf.', u'To'), [u'wake']),
#  ((u'curse', u'awhile.'), [u'Curse,']),
#  ((u'ante-chamber', u'in'), [u'the']),
#  ((u'as', u'provident'), [u'As']),
#  ((u'was', u'dear'), [u'to']),
#  ((u'monstrous,', u'and'), [u'for']),
#  ((u"show'ring", u'on'), [u'your']),
#  ((u'love.', u'that'), [u'my']),
#  ((u'sort', u'As'), [u'if']),
#  ((u'wish,', u'forbear;'), [u'In']),
#  ((u'time', u'made'), [u'me', u'her']),
#  ((u'icy', u'fang'), [u'And']),
#  ((u'descended', u'as'), [u'thyself,']),
#  ((u'Hath,', u'with'), [u'the']),
#  ((u'shores,', u'Caesar'), [u'said']),
#  ((u'from', u'me;'),
#   [u'For',
#    u'But',
#    u'will',
#    u'Let',
#    u'And,',
#    u'say',
#    u'He',
#    u"There's",
#    u'nor',
#    u'So']),
#  ((u'be', u'borne'), [u'alone.', u'to']),
#  ((u'the', u'chapel,'), [u'or']),
#  ((u'dower;', u'For'), [u'can', u'by']),
#  ((u'than', u'Bardolph.'), [u'He']),
#  ((u'day', u'In'), [u'this']),
#  ((u'the', u'heresies'), [u'that']),
#  ((u'pre-surmise', u'That'), [u'in']),
#  ((u'longings', u'in'), [u'me.']),
#  ((u'content', u'and'), [u'you', u'you.', u'seek']),
#  ((u'most', u'peerless'), [u'piece']),
#  ((u'eyes.', u'Take'), [u'notice']),
#  ((u'good', u'how'), [u'you']),
#  ((u'his', u'ear'),
#   [u'Feeds', u"I'll", u"abus'd,", u'that', u'stranger', u'full']),
#  ((u'am', u'rapt,'), [u'and']),
#  ((u'burst', u'his'), [u'head', u'lead', u'mighty']),
#  ((u'rings.', u'Enter'), [u'Lady']),
#  ((u'Portia,', u'what'), [u'mean']),
#  ((u'Philippe,', u'a'), [u'daughter,']),
#  ((u'mean', u'of'), [u'us', u'death,']),
#  ((u'stew,', u'and'), [u'to']),
#  ((u'horrid', u'hent.'), [u'When']),
#  ((u'here', u'put'), [u'in,']),
#  ((u'the', u'heir?'), [u'You']),
#  ((u'name,', u'lead;'), [u'your']),
#  ((u'possible,', u'friend'), [u'Licio,']),
#  ((u'my', u'least'), [u'misuse?']),
#  ((u'on', u'wing'), [u'soaring']),
#  ((u'and', u'flourish'), [u'in', u'in', u'with']),
#  ((u'and', u'sorceries'), [u'terrible']),
#  ((u'could', u'sing,'), [u'would']),
#  ((u'bring', u'To'), [u'frown', u'make']),
#  ((u'Which', u'Lion'), [u'vile']),
#  ((u'map,', u'the'), [u'end']),
#  ((u"stave's", u'end'), [u'as']),
#  ((u'All', u'but'), [u'new', u'in', u'Metellus', u'the', u'mariners']),
#  ((u'served.', u'Delay'), [u'not,']),
#  ((u'your', u'garments'), [u'were']),
#  ((u'his', u'discipline,'), [u'or']),
#  ((u'will', u'fair'), [u'Juliet']),
#  ((u'man:', u'to-day'), [u'he']),
#  ((u'enjoy', u'her?'), [u'Neither']),
#  ((u'by', u'invention;'), [u'Will']),
#  ((u'scolding', u'tongue.'), [u'know']),
#  ((u'write', u'my'), [u'mind.', u'name.', u'name.', u'name;', u'praise.']),
#  ((u'art;', u'but'), [u'his']),
#  ((u'his', u'son-in-law;'), [u'then']),
#  ((u'all', u'gold!'), [u'This']),
#  ((u'his', u'head,'),
#   [u'his',
#    u'do',
#    u'Whose',
#    u'and',
#    u'But',
#    u'and',
#    u'and',
#    u'bearing',
#    u'Unless',
#    u'The',
#    u'as',
#    u'Made',
#    u'and']),
#  ((u'are', u'Persian'), [u'attire;']),
#  ((u'From', u'top'), [u'to', u'of']),
#  ((u'thy', u'hours;'), [u'But']),
#  ((u'curses', u'an'), [u"Eve's"]),
#  ((u'villain,', u'madam?'), [u'Lady.']),
#  ((u'thee', u'fairies'), [u'to']),
#  ((u'he', u'replied,'), [u'It']),
#  ((u'shall', u'succeed'), [u'in']),
#  ((u'stones.', u'Heaven'), [u'take']),
#  ((u'my', u'measure,'), [u'All']),
#  ((u'Although', u'this'), [u'lord']),
#  ((u'keeps,', u'And'), [u'useth']),
#  ((u'flash', u'of'), [u'it.']),
#  ((u'Edward', u'take'), [u'thee']),
#  ((u'own', u'kind,'), [u'all']),
#  ((u'the', u'twin'), [u'Dromio,']),
#  ((u'two', u'clergymen!'), [u'Two']),
#  ((u'sword?', u'Whiles'), [u'see']),
#  ((u'to', u'Fulvia?'), [u'Riotous']),
#  ((u'they', u'which'), [u'brought']),
#  ((u'cannot.', u'What'), [u'would']),
#  ((u'presently.', u'Ham.'), [u'Bid', u'Do']),
#  ((u'Claud.', u'Out'), [u'on']),
#  ((u'a', u'blinking'), [u'idiot']),
#  ((u"cool'd", u'for'), [u'this.']),
#  ((u'and', u'splay'), [u'all']),
#  ((u'Would', u'not'),
#   [u'be',
#    u'this,',
#    u'this',
#    u'have',
#    u'my',
#    u'scape',
#    u'leap',
#    u'have',
#    u'this',
#    u'entreat',
#    u'the',
#    u'infect',
#    u'have;',
#    u'a',
#    u'undergo']),
#  ((u'to', u'hack'), [u'thy']),
#  ((u'no', u'pelf;'), [u'pray']),
#  ((u'Harry', u'of'),
#   [u'England:',
#    u'England!',
#    u"Monmouth's",
#    u'Hereford,',
#    u'Hereford,',
#    u'Hereford,']),
#  ((u'the', u'verdict'), [u'went:']),
#  ((u'dowers', u'digest'), [u'this']),
#  ((u'many', u'bills'), [u'in']),
#  ((u'slave.', u'If'), [u'thou']),
#  ((u'hath', u"mista'en,"), [u'for,']),
#  ((u'most', u'wicked'), [u'Sir', u'speed,', u'fiend!', u'sir,', u'life.']),
#  ((u'leading,', u'the'), [u'sing']),
#  ((u'lofty', u'in'), [u'our']),
#  ((u'be', u'seen?'), [u'Put']),
#  ((u'stout,', u'in'), [u'yellow']),
#  ((u'pure', u'brain,'), [u"Fashion'd"]),
#  ((u'palace', u'the'), [u'capacity']),
#  ((u'fells,', u'you'), [u'know,']),
#  ((u'Love,', u'dateless'), [u'lively']),
#  ((u'is', u'himself,'), [u"marr'd,", u'and']),
#  ((u'me', u'teach'), [u'thee!', u'you']),
#  ((u'Against', u'those'), [u'honors']),
#  ((u'being', u"charg'd,"), [u'we']),
#  ((u'just?', u'For'), [u'shall']),
#  ((u'Antony', u'found'), [u'Julius']),
#  ((u'Claud.', u'All,'), [u'all!']),
#  ((u'dark.', u'Wouldst'), [u'thou']),
#  ((u'blains,', u'Sow'), [u'all']),
#  ((u'which,', u'God'), [u'He']),
#  ((u'hid', u'the'), [u'worse', u'gold']),
#  ((u"look'd", u'but'), [u'they', u'on', u'asquint.', u'with']),
#  ((u'sir;', u'well,'), [u'well.']),
#  ((u"unshak'd", u'That'), [u'temple,']),
#  ((u'ring', u'had'), [u'of']),
#  ((u"harbour'd", u'in'), [u'their']),
#  ((u'rest,', u'Causeless'), [u'have']),
#  ((u'How', u'now?'),
#   [u"Where's",
#    u'Ay,',
#    u'a',
#    u'What',
#    u'What',
#    u'What',
#    u"An't",
#    u'What',
#    u"Where's",
#    u'Are',
#    u"What's",
#    u"Where's",
#    u"Who's",
#    u'interjections?',
#    u'two',
#    u'Who',
#    u'a',
#    u'Please',
#    u"What's"]),
#  ((u'holy', u'wedlock'), [u'bands.']),
#  ((u'Antony-', u'Tug'), [u'him']),
#  ((u'farther', u'than'), [u'my', u'the', u'to', u'the', u'a', u'at']),
#  ((u'day.', u'Exeunt.'), [u'Alarum.', u'1990-1993', u'1990-1993']),
#  ((u'and', u'causeless.'), [u'Hence']),
#  ((u'Gobbo,', u'good'), [u"Launcelot'"]),
#  ((u'there', u'do'), [u'muster', u'fade']),
#  ((u'too', u'angry.'), [u'If']),
#  ((u'there', u'mirth'), [u'in']),
#  ((u'pledge', u'your'), [u'Grace;']),
#  ((u"household's", u'name,'), [u'My']),
#  ((u'by', u'ill.'), [u'So,']),
#  ((u"suck'dst", u'her'), [u'breast']),
#  ((u'thee', u'poison;'), [u'thou']),
#  ((u'shining,', u'and'), [u'so']),
#  ((u'corn,', u'then'), [u'after']),
#  ((u'gown;', u'or'), [u'else']),
#  ((u'moreover,', u'will'), [u'go']),
#  ((u'certain.', u'Ham.'), [u'Up']),
#  ((u'chastity.', u"I'll"), [u'tell']),
#  ((u"Dar'd", u'to'), [u'the']),
#  ((u'be;', u'it'), [u'is']),
#  ((u'His', u'trespass'), [u'yet']),
#  ((u'You', u'shall,'), [u'sir.', u'Mark', u'my']),
#  ((u'virtuous', u'man'), [u'whom']),
#  ((u'incapable;', u'confederates,'), [u'So']),
#  ((u'die', u'among'), [u'our']),
#  ((u'Do,', u'do,'), [u'thou']),
#  ((u'Officers.', u'Valiant'), [u'Othello,']),
#  ((u'nunnery,', u'go.'), [u'Exit.']),
#  ((u'all', u'natures,'), [u'sleep.']),
#  ((u'that', u'occasion'), [u'that']),
#  ((u'boys', u'know'), [u'little']),
#  ((u'lost,', u'quite'), [u'lost;']),
#  ((u'art', u'nothing'), [u'but']),
#  ((u'perfect', u'best'), [u'As']),
#  ((u'covering', u'your'), [u'fearful']),
#  ((u'Older', u'in'), [u'practice,']),
#  ((u'complot', u'to'), [u'betray']),
#  ((u'fines;', u'but'), [u'there']),
#  ((u'but', u'sick'), [u'and']),
#  ((u'Royal', u'sir,'), [u'Since']),
#  ((u'mallard,', u'Leaving'), [u'the']),
#  ((u'hush!', u'Thou'), [u"think'st"]),
#  ((u'all', u'frail.'), [u'Else']),
#  ((u'see', u'old'), [u'age,', u'Gaunt']),
#  ((u'powers,', u'address'), [u'your']),
#  ((u'doth', u'most'), [u'consist', u'mistake', u'lament;']),
#  ((u"rend'red", u'such'), [u'aspect']),
#  ((u'acquaintance,', u'will'), [u'be']),
#  ((u'particular,', u'But'), [u'let']),
#  ((u'Was', u'this'),
#   [u'gentlewoman',
#    u'King',
#    u'easy?',
#    u'ambition?',
#    u'before',
#    u'a',
#    u'upon',
#    u'inserted',
#    u'fair',
#    u'face',
#    u'the',
#    u'the',
#    u'taken']),
#  ((u'world--if', u"'a"), [u'could']),
#  ((u"o'", u'nights,'), [u'Is']),
#  ((u'est', u'France'), [u'et']),
#  ((u'folly.', u'Then,'), [u'heigh-ho,']),
#  ((u'a', u'dance'), [u'ere', u'Of', u'of']),
#  ((u'will', u'implore.'), [u'If']),
#  ((u'should', u'murder'), [u'her?']),
#  ((u'a', u'pad'), [u'conscience.']),
#  ((u'lord', u'Of'), [u'this']),
#  ((u'not', u"asham'd"), [u'With', u'to', u'To']),
#  ((u'main', u"d'une,"), [u'notre']),
#  ((u'ship', u'did'), [u'split,']),
#  ((u'Tapster;', u"what's"), [u'your']),
#  ((u"Harry's", u'company,'), [u'banish']),
#  ((u'wise,', u'amazed,'), [u'temperate']),
#  ((u'guess,', u'That'), [u'we']),
#  ((u'prevented', u'many.'), [u'Eros,']),
#  ((u'Serv.', u'Now'), [u"I'll"]),
#  ((u'his', u'arm'), [u'The', u'in']),
#  ((u'witch', u'And'), [u'straightway']),
#  ((u'all', u'grace.'), [u'Well,']),
#  ((u'Gloucester?', u'Corn.'), [u'Followed']),
#  ((u'That', u'unicorns'), [u'may']),
#  ((u'true', u'perfection,'), [u'or']),
#  ((u'Teach', u'her'), [u'the', u'not']),
#  ((u'happy', u'man'), [u'be', u'be', u"be's"]),
#  ((u'brother,', u'as'), [u'thou']),
#  ((u'is', u'painted'), [u'blind,', u'also']),
#  ((u'rot', u'even'), [u'here.']),
#  ((u'began', u'this?'), [u'On']),
#  ((u'else,', u'nor'), [u'that']),
#  ((u'hole', u'you'), [u'made']),
#  ((u'clock', u'gives'), [u'me']),
#  ((u'is.', u'By'), [u'your']),
#  ((u'men.', u'Let'), [u'him']),
#  ((u'but', u'soft!'), [u'aside!']),
#  ((u'wake', u'my'), [u'cousin']),
#  ((u'her?', u'For'), [u"God's"]),
#  ((u'at', u'heart!'), [u'Pray']),
#  ((u'The', u'vigour'), [u'and']),
#  ((u'a', u'fellow.'), [u'These']),
#  ((u'My', u'vouch'), [u'against']),
#  ((u'us.', u'[Aside]'), [u'would', u'So']),
#  ((u"daughters'", u'minds'), [u'By']),
#  ((u'find', u'Must'), [u'find']),
#  ((u'clock:', u'My'), [u'thoughts']),
#  ((u'these', u'sands'), [u'like']),
#  ((u'utter', u'sweet'), [u'breath;']),
#  ((u'the', u'plain,'), [u'where', u'And']),
#  ((u'than', u'Progne'), [u'will']),
#  ((u'a', u'father!'), [u'Hath', u'had', u'How']),
#  ((u'man;', u'but,'), [u'by']),
#  ((u'meditating', u'with'), [u'two']),
#  ((u'thoughts.', u'Think'), [u'you']),
#  ((u'dearer', u'lord?'), [u'Then,']),
#  ((u'monstrous', u'state.'), [u'Now']),
#  ((u'Butts,', u'The'), [u"King's"]),
#  ((u'dolour', u'to'), [u'another,']),
#  ((u'for', u'wives,'), [u"I'll"]),
#  ((u'spoke', u'on;'), [u'can']),
#  ((u'noble', u'sinews'), [u'of']),
#  ((u'purse', u'when'), [u'he']),
#  ((u'Of', u'such'),
#   [u'a',
#    u'enchanting',
#    u'an',
#    u'as',
#    u'a',
#    u'a',
#    u'misery',
#    u'contents',
#    u'a',
#    u'as',
#    u'possessions,',
#    u'a',
#    u'a',
#    u'divine']),
#  ((u'street', u'should'), [u'see']),
#  ((u'hang', u'me;'), [u'if']),
#  ((u'Well', u'struck'), [u'in']),
#  ((u'heard', u'of;'), [u'for']),
#  ((u'good', u'husband,'), [u'let']),
#  ((u'massacre!', u'see,'), [u'as']),
#  ((u"there's", u'two'), [u"tongues.'"]),
#  ((u'That', u'sleeping'), [u'here']),
#  ((u'madam,', u'would'), [u'it']),
#  ((u'man,', u'my'), [u'father.']),
#  ((u'to-morrow', u'wed'), [u'her.']),
#  ((u'each', u'do'), [u'kill']),
#  ((u'should', u'Be'), [u'free', u'so']),
#  ((u'people', u'of'), [u'this', u'this', u'the', u'Rome,', u'Rome,']),
#  ((u'Go,', u'base'), [u'intruder,']),
#  ((u'the', u'rabble-'), [u'Cats']),
#  ((u'answers', u'every'), [u'one.']),
#  ((u'Windsor', u'should'), [u'lose']),
#  ((u'hang,', u'To'), [u'turn']),
#  ((u'truly', u'worthy'), [u'friend.']),
#  ((u'these', u'stops'), [u'of']),
#  ((u"nun's", u'lip'), [u'to']),
#  ((u'and,', u'hearing'), [u'our']),
#  ((u'my', u'commendations;'), [u'would']),
#  ((u'itself', u'to'),
#   [u'the', u'thee.', u'me.', u'hollow', u'that', u'anything.', u'yours']),
#  ((u'Set', u'at'), [u'liberty;']),
#  ((u"'Las,", u"what's"), [u'the']),
#  ((u'satisfied!', u'Cry'), [u'but']),
#  ((u'hear;', u'what'), [u'say']),
#  ((u'his', u'wishes'), [u'good.']),
#  ((u'Should', u'know'), [u'we']),
#  ((u'Ford,', u'what'), [u'of', u'have', u'hoa!']),
#  ((u'leave', u'for'), [u'nothing', u'the']),
#  ((u'command', u'them'), [u'kill?']),
#  ((u'mark,', u'And'), [u'dares']),
#  ((u'Naples', u'Can'), [u'have']),
#  ((u'thou', u'off;'), [u'When']),
#  ((u'common', u'of'), [u'my']),
#  ((u'mortar-piece,', u'to'), [u'blow']),
#  ((u'[Aside]', u'wish'), [u'not']),
#  ((u'his', u'fits,'), [u'On']),
#  ((u'than', u'sharp'), [u'words,']),
#  ((u'ears,', u'and'),
#   [u'he', u'leaves', u'harmful', u'lips.', u'thus', u'have', u'threatens']),
#  ((u'sacred', u'pity'), [u'hath']),
#  ((u'bravely', u'and'), [u'were']),
#  ((u'lord;', u'it'), [u'is', u'is', u'is', u'can', u'was']),
#  ((u'end,', u'Having'), [u'my']),
#  ((u'his', u'musings;'), [u'but']),
#  ((u'rejoicing?', u'Who'), [u'would']),
#  ((u"pil'd,", u'for'), [u'a']),
#  ((u'Ordained', u'is'), [u'to']),
#  ((u'Had', u'plantation'), [u'of']),
#  ((u'ring', u'from'), [u'you.']),
#  ((u"head?'", u'Amongst'), [u'much']),
#  ((u'hither.', u'She'), [u'returns']),
#  ((u'compartner', u'[Verges],'), [u'with']),
#  ((u'matter,', u'husband?'), [u'Cassio']),
#  ((u'lies,', u'is'), [u'stabbing.']),
#  ((u'go', u'near'), [u'To', u'to', u'to', u'to']),
#  ((u'Illyria.', u"What's"), [u'that']),
#  ((u'Now', u'does'), [u'he', u'he', u'my']),
#  ((u'suns', u'than'), [u'one?']),
#  ((u'not', u'interrupt'), [u'me']),
#  ((u'and', u'Edmund].'), [u'Lear.']),
#  ((u'whereof', u"'tis"), [u"rais'd,"]),
#  ((u'Egeus;', u'is'), [u'not']),
#  ((u'die;', u'and,'), [u'rising']),
#  ((u'will.', u'Kent,'), [u'in']),
#  ((u'meeting,', u'give'), [u'him']),
#  ((u'[Viewing', u'the'), [u'superscription]']),
#  ((u'annoyance', u'to'), [u'the']),
#  ((u'excellent', u'discourse,'), [u'Pretty']),
#  ((u'thus', u'losing'), [u'suit']),
#  ((u'his', u"wife's"),
#   [u'dead;',
#    u'sole',
#    u'head,',
#    u'frailty,',
#    u'inclination;',
#    u'love.',
#    u"leman.'",
#    u"kill'd.",
#    u'allies;']),
#  ((u'offend', u'not'), [u'to']),
#  ((u'the-', u'Very'), [u'hand']),
#  ((u'thou', u'believe,'), [u'Orlando,']),
#  ((u'should', u'fight'), [u'withal,', u'with']),
#  ((u'father', u'owning'), [u'it-']),
#  ((u'money,', u'with'), [u'no']),
#  ((u'our', u'wishes'), [u'prosper']),
#  ((u'other', u'means'), [u'to', u'was', u'is']),
#  ((u"'good", u"devil'"), [u'were']),
#  ((u'Unite', u'comutual'), [u'in']),
#  ((u'Westmoreland.', u'Health'), [u'and']),
#  ((u'content.', u'If'), [u'thou']),
#  ((u'King;', u'our'), [u'power']),
#  ((u'another', u'emphasis!'), [u'Say']),
#  ((u'here!', u'for'), [u"heaven's"]),
#  ((u'a', u'daisy.'), [u'would']),
#  ((u'dwell', u'In'), [u'such', u'this']),
#  ((u'survey', u'the'), [u'plot,', u'Tower', u'bodies', u'vantage']),
#  ((u'and', u'oared'), [u'Himself']),
#  ((u'to', u'extol'), [u'her']),
#  ((u'some', u'vile'), [u'thing', u'forfeit']),
#  ((u'you', u'princes,'), [u'Do']),
#  ((u'in', u'Aquitaine,'), [u'And']),
#  ((u'scar', u'to'), [u'scorn;']),
#  ((u'To', u'entertain'),
#   [u'the', u'it', u'the', u'my', u'great', u'these', u'me', u'your']),
#  ((u'dead,', u'shall'), [u'have']),
#  ((u'got,', u'Which'), [u'for']),
#  ((u'ours-', u"long-tongu'd"), [u'babbling']),
#  ((u'displeasure', u'is'), [u'but']),
#  ((u'out', u'to'),
#   [u'the',
#    u'each,',
#    u'suppress',
#    u'hide',
#    u'naught.',
#    u'the',
#    u'prey.',
#    u'seek',
#    u'savage',
#    u'have.',
#    u'sea.',
#    u'be',
#    u'who',
#    u'murder;']),
#  ((u'new', u'things'), [u'disdain;']),
#  ((u'of', u'herdsmen.'), [u'One']),
#  ((u'John.', u'Exit'), [u'Enter']),
#  ((u'Are', u"march'd"), [u'up']),
#  ((u'Your', u"Caesar's"), [u'father']),
#  ((u'sad,', u'for'), [u'he']),
#  ((u'gracious', u'mistress.'), [u'Satisfy']),
#  ((u'sinful', u'fact.'), [u'But']),
#  ((u'know.', u'What'), [u'a', u'dost']),
#  ((u'your', u'pocket,'), [u'like', u'sir,']),
#  ((u'prithee;', u'but'), [u'yet']),
#  ((u'manner', u'person'), [u'Have']),
#  ((u'Pompey,', u'ha?'), [u'Come']),
#  ((u'Bolingbroke', u'to'), [u'England.', u'be']),
#  ((u'another?', u"What's"), [u'their']),
#  ((u'Yield', u'up,'), [u'love,']),
#  ((u'say', u'they?'), [u'Such', u'Nothing']),
#  ((u'Draw,', u'Bardolph.'), [u'Cut']),
#  ((u'presents', u'itself.'), [u'do']),
#  ((u'molehill', u'here'), [u'That']),
#  ((u'be', u"cover'd"), [u'With']),
#  ((u'deserts', u'idle,'), [u'Rough']),
#  ((u'this', u'ruin'), [u'of']),
#  ((u'Fran.', u'Let'), [u'me']),
#  ((u'join', u'you'), [u'together', u'with', u'with', u'with']),
#  ((u'helpful', u'swords.'), [u'God,']),
#  ((u"Eleanor's", u'aspiring'), [u'humour,']),
#  ((u'well;', u'commend'), [u'me', u'me']),
#  ((u'Is', u'Paris'), [u'lost?']),
#  ((u'creatures', u'works!'), [u'Yea,']),
#  ((u'some', u'scurvy'), [u'fellow.']),
#  ((u'a', u'cherubin'), [u'Thou']),
#  ((u'Prove', u'this,'), [u'thou']),
#  ((u'the', u'grace,'), [u'the', u'Despite', u'Voice,']),
#  ((u'lest', u'thy'), [u'pity']),
#  ((u'Excusing', u'thy'), [u'sins']),
#  ((u'could', u'hear'), [u'no']),
#  ((u'Troy', u'walls'), [u'stand;']),
#  ((u'that', u'gat'), [u'thee,']),
#  ((u'Wherefore', u'sent'), [u'for']),
#  ((u"o'er.", u'With'), [u'millstones.']),
#  ((u'attendants', u'We'), [u'will']),
#  ((u'lead.', u"'Who"), [u'chooseth']),
#  ((u'Henry', u'afterwards'), [u'married']),
#  ((u'talks', u'as'), [u'familiarly', u'if']),
#  ((u'me;', u'Here'), [u'will']),
#  ((u'whose', u'several'), [u'ranges']),
#  ((u'Then', u'gentle'), [u'cheater']),
#  ((u'of', u"Gloucester's"),
#   [u'men,', u'grove', u'Castle.', u'death,', u'purse!']),
#  ((u'which', u'receive'), [u'much']),
#  ((u'demonstrate', u'thinly.'), [u"I'll"]),
#  ((u'dreamt', u'she'), [u'was']),
#  ((u'side.', u'Loud'), [u'alarum.']),
#  ((u'In', u'aid'), [u'whereof']),
#  ((u'wisdom.', u'Fare'), [u'you']),
#  ((u'great', u'rich'), [u'Capulet;']),
#  ((u'know,', u'so'), [u'shall']),
#  ((u'tied', u'unto'), [u'his']),
#  ((u'else?', u'And,'), [u'but']),
#  ((u'The', u'Alps'), [u'doth']),
#  ((u'act', u'or'), [u'two;', u'will']),
#  ((u'chance.', u'Your'), [u'face']),
#  ((u'mistress,', u'one'), [u'sweet']),
#  ((u'made,', u'a'), [u'poor']),
#  ((u'too.', u'would'), [u'had', u'my', u'not']),
#  ((u'your', u'fellow'), [u'too,', u'tribune', u'is', u'You']),
#  ((u'directly', u'and'), [u'truly-', u'briefly,']),
#  ((u'Salisbury,', u'And'), [u'he', u'with']),
#  ((u'than', u'all.'), [u'The']),
#  ((u'Whose', u'aged'), [u'honour']),
#  ((u'and', u'Macduff.'), [u'Let']),
#  ((u'close.', u'Inquire'), [u'me']),
#  ((u'maid', u'full'), [u'pale,']),
#  ((u'To', u'hurl'), [u'at', u'upon']),
#  ((u'But,', u'after'), [u'all']),
#  ((u'them!', u"What's"), [u'thy']),
#  ((u'for', u'trifles;'), [u'his']),
#  ((u'thrive', u'Richard'), [u'as']),
#  ((u'thee', u"wond'red"), [u'at.']),
#  ((u'and', u'clerk?'), [u'Well']),
#  ((u'lies', u'your'),
#   [u"grief?'",
#    u'love.',
#    u'niece,',
#    u'power?',
#    u'way;',
#    u'brother,',
#    u'way.',
#    u'text?',
#    u'way,']),
#  ((u'well-', u'this'), [u'satisfaction']),
#  ((u'which', u'disguise,'), [u'While']),
#  ((u'King.', u'Break'), [u'not']),
#  ((u'with', u'glorious'), [u'fame.']),
#  ((u'ruffian', u'And'), [u'seek']),
#  ((u'plumes.', u'short'), [u'alarum]']),
#  ((u'begin', u'once,'), [u"he'll"]),
#  ((u'end', u'As'), [u'all', u'give']),
#  ((u'and', u'may'),
#   [u'save', u'do', u'be', u'by', u'thee.', u'not', u'look', u'not']),
#  ((u'Whereon', u'his'), [u'brains']),
#  ((u'and', u'lady!'), [u'My']),
#  ((u'more.', u'But'), [u'let', u"I'll"]),
#  ((u'Enter', u'If'), [u'my']),
#  ((u'journey', u'dull'), [u'and']),
#  ((u'fight,', u'What'), [u'a']),
#  ((u'live', u'But'), [u'that', u'to', u'in']),
#  ((u'subject', u'to'),
#   [u'the',
#    u'invent',
#    u"time's",
#    u'his',
#    u'the',
#    u'the',
#    u'a',
#    u'your',
#    u'you?',
#    u'this',
#    u'fears;',
#    u'a',
#    u'the',
#    u'heat',
#    u'thy',
#    u'a',
#    u'a',
#    u'the']),
#  ((u"Offence's", u'gilded'), [u'hand']),
#  ((u'joyous.', u'But'), [u'is']),
#  ((u'further', u'enemy'), [u'to']),
#  ((u'Justice,', u'Gaoler,'), [u'Servants,']),
#  ((u"hand.What's", u'done'), [u'cannot']),
#  ((u'laugh', u'a'), [u'little.', u'siege']),
#  ((u'cruel', u'hand.'), [u'Is']),
#  ((u'The', u"slave's"), [u'report']),
#  ((u"I'm", u'sorry'), [u"for't;"]),
#  ((u'with', u'beauty;'), [u'violets,']),
#  ((u'move;', u'Doubt'), [u'truth']),
#  ((u'one,', u'And'), [u'means', u'in', u'at', u'yet']),
#  ((u'heart,', u'With'), [u'sounding']),
#  ((u'me?', u'Mer.'), [u'Good']),
#  ((u'rolls,', u'and'), [u'rolls,', u'rolls.']),
#  ((u'creeping', u'fowler'), [u'eye,']),
#  ((u'papers', u'lie'), [u'like']),
#  ((u'generally', u'is'), [u'at']),
#  ((u'Your', u'laboursome'), [u'and']),
#  ((u'as', u'prodigal'), [u'of']),
#  ((u'gross;', u'fat,'), [u'fat.']),
#  ((u'owl.', u'All'), [u'is']),
#  ((u'window', u'bars'), [u'bore']),
#  ((u'and', u'such-like'), [u'trifles,']),
#  ((u'done', u'all'), [u'this', u'this.', u'this.']),
#  ((u'Scot.', u'Doug.'), [u"All's"]),
#  ((u'idle', u'words;'), [u'For']),
#  ((u'Edward.', u'No,'), [u'wrangling']),
#  ((u'thee,', u'if'), [u'it', u'dreams', u'thou', u'it', u'not', u'the']),
#  ((u'Thy', u'great'), [u'employment']),
#  ((u'pride.', u'Comfort,'), [u'my']),
#  ((u'in', u'it!'), [u'Men']),
#  ((u'and', u'worthiest'), [u'To']),
#  ((u'badness', u'reign.'), [u'Thy']),
#  ((u'with', u'scorn'), [u"shov'd"]),
#  ((u'fools!', u'Re-enter'), [u'Madam,']),
#  ((u'worthy', u'lady,'), [u'hold,', u'to', u'And']),
#  ((u'hot,', u'too'), [u'hot!']),
#  ((u'he', u"lov'd"), [u'his', u'so', u'her', u'her']),
#  ((u'the', u'elder.'), [u'If']),
#  ((u'spirits', u'to'), [u'your', u'arms,']),
#  ((u'keeps', u'due'), [u'on']),
#  ((u'Scarlet,', u'and'), [u'John.']),
#  ((u'Guil.', u'know,'), [u'no']),
#  ((u'got', u'on'), [u'the']),
#  ((u'now', u'loud-howling'), [u'wolves']),
#  ((u'mention', u'it'), [u'within']),
#  ((u"shak'st", u'thy'), [u'head,']),
#  ((u'become', u'Of'), [u'the']),
#  ((u'misery,', u'Beats'), [u'in']),
#  ((u'the', u'disease,'), [u'Feeding', u'for', u'and']),
#  ((u'this', u'ass'), [u'now']),
#  ((u'fool-', u'the'), [u'way']),
#  ((u'all-eating', u'shame,'), [u'and']),
#  ((u'locks', u'Of'), [u'prison']),
#  ((u'And', u'saved'), [u'my']),
#  ((u'further;', u'Take'), [u'some']),
#  ((u'world', u'can'), [u'do', u'make', u'say', u'speak,', u'more', u'match']),
#  ((u'in', u'fire,'), [u'To', u'cat']),
#  ((u'a', u'touch'), [u'more', u'of', u'of', u'of']),
#  ((u'Hot.', u'Hath'), [u'Butler']),
#  ((u'out', u'shames'), [u'and']),
#  ((u'Yet', u'more'), [u'quarrelling']),
#  ((u'Elephant;', u'Yet'), [u'there']),
#  ((u'Gon.', u'Welcome,'), [u'my']),
#  ((u'thou', u'attend'), [u'me?', u'me;']),
#  ((u'serve', u'my'),
#   [u'turn?', u'turn,', u'turn;', u'turn', u'turn', u'turn,']),
#  ((u'fight', u'is,'), [u'beside']),
#  ((u'sir,', u'was'),
#   [u'profitable;', u"lapp'd", u"Yorick's", u'not', u'Carthage.']),
#  ((u'stand', u'no'), [u'farther']),
#  ((u'thither', u'straight,'), [u'for']),
#  ((u'air,', u"Th'"), [u'extravagant']),
#  ((u'wronged', u'maid'), [u'to']),
#  ((u'days', u'To'), [u'the', u'the']),
#  ((u'Speaks', u'to'), [u'atone']),
#  ((u'hence', u'attend'), [u'dispatch.']),
#  ((u'the', u'Northgate.'), [u'Go,', u'For']),
#  ((u'whose', u'guiltless'), [u'drops']),
#  ((u'guilt.', u'Exit.'), [u'Knocking']),
#  ((u'that', u'year'), [u'miscarry.', u'on']),
#  ((u"th'", u'ambassadors.'), [u'My']),
#  ((u"pluck'd", u'down.'), [u'And']),
#  ((u'First,', u'began'), [u'in']),
#  ((u'not;', u'fly'), [u'whilst']),
#  ((u'bounteous', u'nature'), [u'Hath']),
#  ((u'in', u'blessings'), [u'on']),
#  ((u'in', u'register'), [u'master-leaver']),
#  ((u'goods', u'confiscate'), [u'to']),
#  ((u'Charles', u'his'), [u'gleeks?', u'father.']),
#  ((u'power', u'pities'), [u'wretched']),
#  ((u'can', u'die'), [u'but']),
#  ((u'be', u'deposed?'), [u"Depress'd"]),
#  ((u'Yet', u'express'), [u'to']),
#  ((u'happy,', u'and'), [u'too', u'has']),
#  ((u'particular', u'paper'), [u'edition.']),
#  ((u'solely', u'led'), [u'By']),
#  ((u'day!', u"he's"), [u'gone,']),
#  ((u'and', u'robbers'), [u'range']),
#  ((u'napkin,', u'And'), [u'let']),
#  ((u'Things', u'at'), [u'the']),
#  ((u'chaste,', u'and,'), [u'brother,']),
#  ((u'position', u'portend?'), [u'If']),
#  ((u'do', u'couch'), [u'on']),
#  ((u'upon', u'him,'),
#   [u'speak',
#    u'And',
#    u'but',
#    u'love',
#    u'that',
#    u'till',
#    u'that',
#    u'as',
#    u'you',
#    u'Like',
#    u'sir,',
#    u'as',
#    u'yet',
#    u'With',
#    u'dog!',
#    u"Surpris'd",
#    u'niece;',
#    u'mean?',
#    u'for',
#    u'Priam,',
#    u'where']),
#  ((u'a', u'villager'), [u'Than']),
#  ((u'The', u'galleys'), [u'Have']),
#  ((u'fell', u'distract,'), [u'And']),
#  ((u'my', u'factor,'), [u'good']),
#  ((u'with', u'holy'), [u'bell', u'prayers;', u'abstinence', u'words,']),
#  ((u'all,', u'save'), [u'thee,']),
#  ((u'fit', u'As'), [u"Caesar's"]),
#  ((u'remorse', u'They'), [u'could']),
#  ((u'walks', u'till'), [u'the']),
#  ((u'livelihood', u'he'), [u"show'd"]),
#  ((u'faint', u'you,'), [u'lords?']),
#  ((u'chess', u'Sweet'), [u'lord,']),
#  ((u'blood', u'thrill'), [u'at']),
#  ((u'down', u'Perforce'), [u'must']),
#  ((u'was', u"fix'd,"), [u"Fast'ned"]),
#  ((u'Will', u'seek'), [u'them']),
#  ((u'Nor', u'need'), [u'tallies', u'you,']),
#  ((u'confusion,', u'thou'), [u'shalt']),
#  ((u'vows', u'made'), [u'in']),
#  ((u'alas!', u'What,'), [u'in']),
#  ((u'French-crown-colour', u'beard,'), [u'your']),
#  ((u'distemper?', u'You'), [u'do']),
#  ((u'fear', u'this;'), [u'for']),
#  ((u'cause', u'into'), [u'the', u'his']),
#  ((u'The', u'Cardinal!'), [u'Observe,']),
#  ((u'Captain.', u'Exit'), [u'Officer']),
#  ((u'poverty', u'could'), [u'never']),
#  ((u'press', u'not'), [u'so']),
#  ((u'execution', u'sworn.'), [u'do']),
#  ((u'left', u"untender'd."), [u'And,']),
#  ((u'That', u'cravens'), [u'my']),
#  ((u'so.', u'Disparage'), [u'not']),
#  ((u'no?', u'What,'), [u'are']),
#  ((u'suck', u'them'), [u'up', u'dry,']),
#  ((u'fortnight', u'ill;'), [u'And']),
#  ((u'Nile,', u'whose'), [u'breath']),
#  ((u'More', u'guarded'), [u'than']),
#  ((u'or', u'wrong,'), [u'Lord']),
#  ((u'another', u'device'), [u'in']),
#  ((u'life', u'besiege.'), [u'Farewell,']),
#  ((u'lined', u'their'), [u'coats']),
#  ((u'eye,', u'of'), [u'brow,']),
#  ((u'lord;', u'away,'), [u'take']),
#  ((u'sea,', u'in'), [u'sky.']),
#  ((u'purest', u'treasure'), [u'mortal']),
#  ((u'For', u'hear'), [u'her']),
#  ((u'revolve', u'and'), [u'ruminate']),
#  ((u'To', u'arms'), [u"let's", u'invasive?']),
#  ((u'withal.', u'Thou'), [u'art']),
#  ((u'the', u'meads,'), [u'Confounds']),
#  ((u'plays]', u'Music'), [u'do']),
#  ((u'there,', u'a'), [u'way']),
#  ((u'men', u'like'), [u'angels', u'a', u'dogs!', u'one', u'you,', u'blasted']),
#  ((u'Though', u'Nature'), [u'hath']),
#  ((u'[Lifts', u'up'), [u'the']),
#  ((u'such', u'man;'), [u'you', u'for,', u'it']),
#  ((u'Hector,', u'that,'), [u'that,']),
#  ((u'lady,', u'your'), [u'niece;']),
#  ((u'shamefully', u'misplaced,'), [u'And']),
#  ((u'Blunt.', u'Shall'), [u'return']),
#  ((u'senses,', u'better'), [u"pleas'd"]),
#  ((u'our', u'gentle-hearted'), [u'king.']),
#  ((u"yoke.'", u'Bene.'), [u'The']),
#  ((u'best', u'ends'), [u'You']),
#  ((u'Prince', u'shall'), [u'follow']),
#  ((u'hiding', u'of'), [u'the']),
#  ((u'knight', u'should'), [u'violate!-']),
#  ((u'meat', u'to-day,'), [u'nor']),
#  ((u'there,', u'butcher?'), [u'cannot']),
#  ((u'Lear.', u'Because'), [u'they']),
#  ((u'me,', u'Lysander,'), [u'help']),
#  ((u'It', u'illumineth'), [u'the']),
#  ((u'That', u'assure'), [u'you:']),
#  ((u'exhibition', u'to'), [u'examine.']),
#  ((u'firm.', u'Bur.'), [u'am']),
#  ((u'For', u'the'),
#   [u'ballad',
#    u'contempt',
#    u'main',
#    u'best',
#    u'most',
#    u'Queen,',
#    u'dearth,',
#    u'mutable,',
#    u'whole',
#    u'inheritance',
#    u'most',
#    u'apparel',
#    u'supply',
#    u'law',
#    u'demand',
#    u'sugar',
#    u'hot',
#    u'time',
#    u'robbery,',
#    u'box',
#    u'Prince',
#    u'boy-',
#    u'women?',
#    u'fifth',
#    u'only',
#    u'Dauphin:',
#    u'best',
#    u'base',
#    u'repealing',
#    u'sound',
#    u'rain',
#    u'form-',
#    u'following,',
#    u'rest',
#    u"Lord's",
#    u'latter',
#    u'ass',
#    u'remembrance',
#    u'ingredients',
#    u"blood-bolter'd",
#    u'whole',
#    u'most',
#    u'benefit',
#    u'four',
#    u'which,',
#    u'close',
#    u'commodity',
#    u'table,',
#    u'intent',
#    u'which',
#    u'letter',
#    u'which',
#    u'which,',
#    u"sea's",
#    u'fair',
#    u'whole',
#    u'deposing',
#    u'instalment',
#    u'selfsame',
#    u'like',
#    u'Lord',
#    u'offence',
#    u'great',
#    u'wide',
#    u'capacity',
#    u'enfreed',
#    u'love',
#    u'fair',
#    u'love',
#    u'love',
#    u'rain',
#    u'rain',
#    u'rain',
#    u'rain',
#    u'fail',
#    u'red']),
#  ((u'shall', u'shake'), [u'thy', u'off', u'him']),
#  ((u'his', u'exchequer'), [u'is']),
#  ((u'yet', u'methinks'),
#   [u'have', u'it', u'my', u'you', u'your', u'right', u'it', u'see', u'do']),
#  ((u'him?', u'Bene.'), [u'Troth,']),
#  ((u'thou', u'use'), [u'So', u'to', u'me', u'thy', u'to']),
#  ((u'other', u'turns'), [u'to']),
#  ((u'these', u'strawberries.'), [u'His']),
#  ((u'forbid', u'so'), [u'many']),
#  ((u'of', u'tippling'), [u'with']),
#  ((u'gentle', u'friend,'), [u'for', u'How', u'Let']),
#  ((u'to', u'bliss,'), [u'as']),
#  ((u'bitterly', u'on'), [u'you']),
#  ((u'more', u'words.'), [u'[Exeunt', u'Away,', u'The']),
#  ((u'art.', u'Be'), [u'not']),
#  ((u'butcher', u'with'), [u'an']),
#  ((u'hence', u'today?'), [u'He']),
#  ((u'that', u'truly'), [u'which', u'did', u'loves']),
#  ((u'fire,', u'to'), [u'say', u'ride']),
#  ((u'the', u'tidings,'), [u'Which']),
#  ((u'on', u'thyself.'), [u'[Coming']),
#  ((u'Prince,', u'my'), [u'son-', u'brother,']),
#  ((u'one', u'thrice'), [u'told?', u'worse']),
#  ((u'any', u'language.'), [u'think,']),
#  ((u'and', u"cross-garter'd,"), [u'even', u'a']),
#  ((u'send', u'them'),
#   [u'back',
#    u'to',
#    u'to',
#    u'dinners',
#    u'now.',
#    u'all',
#    u'word',
#    u'after',
#    u'thither.',
#    u'back',
#    u'both.',
#    u'flying.']),
#  ((u'you', u'chance'), [u'to', u'to']),
#  ((u'strong', u'fellow'), [u'by']),
#  ((u'moon,', u'As'), [u'sun']),
#  ((u'sir;', u'fear,'), [u'sir,']),
#  ((u'severe', u'a'), [u'moraler.']),
#  ((u'the', u'lamb'), [u'here', u'that']),
#  ((u'with', u'kings.'), [u'When']),
#  ((u'labour,', u'nor'), [u'that']),
#  ((u'place.', u'Who'), [u'governs']),
#  ((u'thou', u'leave?'), [u'Thy']),
#  ((u'thou', u'thereby'), [u'Mayst']),
#  ((u'have', u'heard:'), [u'Swear']),
#  ((u'full.', u'Here'), [u'is']),
#  ((u'Here', u'all'), [u'eyes']),
#  ((u'it,', u'Henry,'), [u'and']),
#  ((u'several', u'printed'), [u'editions,']),
#  ((u'bitter', u'is'), [u'thy']),
#  ((u'assurance;', u'and'), [u'Give']),
#  ((u'so', u'wise'), [u'To', u'As']),
#  ((u'nearer', u'debt'), [u'in']),
#  ((u'succession', u'be'), [u"determin'd."]),
#  ((u'you', u'sir.'), [u"That's"]),
#  ((u'her', u'needle,'), [u'an']),
#  ((u'Pray,', u'innocent,'), [u'and']),
#  ((u'much', u'drink'), [u'may']),
#  ((u"I'll", u'weep.'), [u'No,', u'fool,']),
#  ((u'villain!', u'Draw'), [u'and']),
#  ((u'wife;', u'he'), [u'will']),
#  ((u'two', u'villains,'), [u'whose']),
#  ((u'Thou', u"robb'st"), [u'me']),
#  ((u'sights,', u'Shake'), [u'patiently']),
#  ((u'blunt', u'a'), [u'will,']),
#  ((u'Reason,', u'in'), [u'madness!']),
#  ((u'did', u'sleep'), [u'day', u'under']),
#  ((u'Where', u"dwell'st"), [u'thou?']),
#  ((u'the', u'fact'), [u'with']),
#  ((u'Ah,', u'so'), [u'much']),
#  ((u"greatness,'-", u'What'), [u"say'st"]),
#  ((u'accusation;', u'and'), [u'briefly,']),
#  ((u'Exit', u'You'),
#   [u'have', u'have', u'may', u'see,', u'do', u'have', u'are', u'have']),
#  ((u'swabber,', u'the'), [u'boatswain,']),
#  ((u'pilgrimage', u'to'), [u'thee,', u'Saint']),
#  ((u'pictures;', u"'tis"), [u'the']),
#  ((u'daughter.', u'Lear.'), [u'Ha!', u'No.']),
#  ((u'and', u'confounds'), [u'him']),
#  ((u'mute,', u'When'), [u'others']),
#  ((u'death', u'If'), [u'thou', u'did']),
#  ((u'or', u'white,'), [u'Tooth']),
#  ((u'comes', u'this?'), [u'Gon.']),
#  ((u'Boils', u'and'), [u'plagues']),
#  ((u'meant', u'all'), [u'harm.']),
#  ((u'planet,', u'that'), [u'will']),
#  ((u'our', u"Marcius'"), [u'banishment,']),
#  ((u'forbid', u'all'), [u'names;']),
#  ((u'the', u'sanctuary.'), [u'Exeunt']),
#  ((u'Many', u'good'), [u'morrows', u'nights,', u'morrows', u'morrows']),
#  ((u'thee,', u'Rosalind,'), [u'sweet', u'for', u'for']),
#  ((u'go.', u'Fal.'), [u'Well,']),
#  ((u'too.', u'Went'), [u'it']),
#  ((u'Let', u'housewives'), [u'make']),
#  ((u'helm.', u'Besides,'), [u'he']),
#  ((u'man.', u'Wherefore?'), [u'wherefore?']),
#  ((u'feeder', u'of'), [u'my']),
#  ((u'the', u'height,'), [u'are']),
#  ((u'Marcius,', u'We'), [u'have']),
#  ((u'this', u'novice;'), [u'and']),
#  ((u'forgive', u'you.'), [u'Live,']),
#  ((u"amaz'd", u'me'), [u'more']),
#  ((u"body's", u'members'), [u"Rebell'd"]),
#  ((u'with', u'true'), [u'sight,', u'prayers']),
#  ((u'love', u'not;'), [u'for']),
#  ((u'King', u'hereafter!'), [u'Good']),
#  ((u'duly', u'waited'), [u'for']),
#  ((u'Christian', u'shame,'), [u'put']),
#  ((u'rather', u'thought'), [u'you']),
#  ((u'our', u'Ajax.'), [u'As']),
#  ((u'cave,', u'and'), [u'[To', u'a', u'bring']),
#  ((u'upon', u'that.'), [u'Our']),
#  ((u'pastime,', u'tired'), [u'out']),
#  ((u'spent,', u'Where'), [u'our']),
#  ((u'poor', u'beseeming;'), [u"'twas"]),
#  ((u'further', u'pleasure'), [u'is-', u'Be']),
#  ((u'Queen', u'by'), [u'a']),
#  ((u'weight', u'from'), [u'off']),
#  ((u'pains.', u'Farewell.'), [u'Commend']),
#  ((u'our', u'senators'), [u'for']),
#  ((u'peace,', u'and'),
#   [u'happiness,', u'prayer.', u"purchas'd", u'all', u'part', u'he', u'wake']),
#  ((u'low,', u'And'), [u'browner', u'some']),
#  ((u'porches', u'of'), [u'my']),
#  ((u"confirm'd", u'honesty.'), [u'will']),
#  ((u'lazy', u'yawning'), [u'drone.']),
#  ((u'blow.', u'Tyb.'), [u'You']),
#  ((u'And', u'George,'), [u'of']),
#  ((u'sleeping', u'wolf.'), [u'To']),
#  ((u'Were', u'equal'), [u'poise']),
#  ((u'Me', u'cause'), [u'to']),
#  ((u'more', u'swelling'), [u'port']),
#  ((u'lets', u'not'), [u'bounty']),
#  ((u'Time', u'withal?'), [u'With']),
#  ((u'ambition', u'in'), [u'my', u'the']),
#  ((u'measure,', u'and'), [u'for', u'a', u'be']),
#  ((u'me', u'speak.'),
#   [u'Exeunt',
#    u'Ay,',
#    u'Speak,',
#    u'As',
#    u'Well,',
#    u'have',
#    u'Cut',
#    u'Tullus!',
#    u'Thou',
#    u'Thou',
#    u'But',
#    u'Defy',
#    u'Come',
#    u'Peace,',
#    u'The',
#    u'Well,',
#    u"I'll",
#    u'Assist',
#    u'Madam,',
#    u'You',
#    u'Enter',
#    u'Freely,']),
#  ...]

# %%
sc.parallelize([(1,(3,1)),(1,(3,1)),(2,(1,2)),(4,(1,2))]).reduceByKey(lambda x, y: x+y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-71d85d783fcc> in <module>()
# ----> 1 sc.parallelize([(1,(3,1)),(1,(3,1)),(2,(1,2)),(4,(1,2))]).lookup(1).reduceByKey(lambda x, y: x+y)
#
# AttributeError: 'list' object has no attribute 'reduceByKey'
